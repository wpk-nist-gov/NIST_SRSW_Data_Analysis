# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_bino = pd.read_csv('../data/processed/LJ_PURE/LJ_3sigma_LRC_TMMC/bino-ave.csv')
df_spin = pd.read_csv('../data/processed/LJ_PURE/LJ_3sigma_LRC_TMMC/spin-ave.csv')

# %%
df_bino.plot('dens','temp', marker='o', ls='None', ax=plt.gca())

df_spin.query('phase==spinodal').plot('dens','temp',marker='o',ls='None', ax=plt.gca())
# Out:
# <Axes: xlabel='dens'>
